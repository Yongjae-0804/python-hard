# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('atmospher.csv', encoding = 'cp949', index_col = 0)
df.head()
# Out:
#            측정일시  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 0  202207281200   강북구         0.008      0.055           0.3       0.002
# 1  202207281200  서대문구         0.009      0.057           0.4       0.003
# 2  202207281200   양천구         0.009      0.057           0.3       0.002
# 3  202207281200   금천구         0.011      0.062           0.3       0.003
# 4  202207281200   성북구         0.014      0.054           0.3       0.002
#
#    미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 0       31.0        20.0
# 1       19.0        14.0
# 2       26.0        17.0
# 3       26.0        22.0
# 4       27.0        14.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4200 entries, 0 to 4199
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   측정일시          4200 non-null   int64
#  1   측정소명          4200 non-null   object
#  2   이산화질소농도(ppm)  4123 non-null   float64
#  3   오존농도(ppm)     4121 non-null   float64
#  4   일산화탄소농도(ppm)  4122 non-null   float64
#  5   아황산가스(ppm)    4123 non-null   float64
#  6   미세먼지(㎍/㎥)     4072 non-null   float64
#  7   초미세먼지(㎍/㎥)    4101 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 262.6+ KB

# %%
df.describe()
# Out:
#                측정일시  이산화질소농도(ppm)    오존농도(ppm)  일산화탄소농도(ppm)   아황산가스(ppm)  \
# count  4.200000e+03   4123.000000  4121.000000   4122.000000  4123.000000
# mean   2.022072e+11      0.012930     0.039568      0.381951     0.002493
# std    2.048041e+04      0.005553     0.022211      0.086082     0.000638
# min    2.022072e+11      0.002000     0.001000      0.100000     0.001000
# 25%    2.022072e+11      0.009000     0.026000      0.300000     0.002000
# 50%    2.022073e+11      0.012000     0.036000      0.400000     0.002000
# 75%    2.022073e+11      0.016000     0.049000      0.400000     0.003000
# max    2.022073e+11      0.044000     0.149000      0.700000     0.013000
#
#          미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# count  4072.000000  4101.00000
# mean     24.967583    16.05901
# std      11.182325     9.25566
# min       3.000000     1.00000
# 25%      16.000000     9.00000
# 50%      23.000000    14.00000
# 75%      32.000000    22.00000
# max      78.000000    55.00000

# %%
df.columns
# Out:
# Index(['측정일시', '측정소명', '이산화질소농도(ppm)', '오존농도(ppm)', '일산화탄소농도(ppm)',
#        '아황산가스(ppm)', '미세먼지(㎍/㎥)', '초미세먼지(㎍/㎥)'],
#       dtype='object')

# %%
df['측정일시']  = pd.to_datetime(df['측정일시'],
                            format='%Y%m%d%H%M')#소문자 y는 두자리 연도
df.head()
# Out:
#                  측정일시  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  \
# 0 2022-07-28 12:00:00   강북구         0.008      0.055           0.3
# 1 2022-07-28 12:00:00  서대문구         0.009      0.057           0.4
# 2 2022-07-28 12:00:00   양천구         0.009      0.057           0.3
# 3 2022-07-28 12:00:00   금천구         0.011      0.062           0.3
# 4 2022-07-28 12:00:00   성북구         0.014      0.054           0.3
#
#    아황산가스(ppm)  미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 0       0.002       31.0        20.0
# 1       0.003       19.0        14.0
# 2       0.002       26.0        17.0
# 3       0.003       26.0        22.0
# 4       0.002       27.0        14.0

# %%
df['측정소명'].unique()
# Out:
# array(['강북구', '서대문구', '양천구', '금천구', '성북구', '관악구', '종로구', '노원구', '강동구',
#        '광진구', '중구', '강남구', '영등포구', '동대문구', '송파구', '성동구', '은평구', '마포구',
#        '도봉구', '강서구', '중랑구', '동작구', '서초구', '구로구', '용산구'], dtype=object)

# %%
len(df['측정소명'].unique())
# Out:
# 25

# %%
df['측정소명'].nunique()
# Out:
# 25

# %%
df
# Out:
#                     측정일시  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  \
# 0    2022-07-28 12:00:00   강북구         0.008      0.055           0.3
# 1    2022-07-28 12:00:00  서대문구         0.009      0.057           0.4
# 2    2022-07-28 12:00:00   양천구         0.009      0.057           0.3
# 3    2022-07-28 12:00:00   금천구         0.011      0.062           0.3
# 4    2022-07-28 12:00:00   성북구         0.014      0.054           0.3
# ...                  ...   ...           ...        ...           ...
# 4195 2022-07-21 13:00:00   성동구         0.014      0.039           0.3
# 4196 2022-07-21 13:00:00   마포구         0.011      0.039           0.3
# 4197 2022-07-21 13:00:00  서대문구         0.007      0.038           0.4
# 4198 2022-07-21 13:00:00   서초구         0.016      0.035           0.3
# 4199 2022-07-21 13:00:00   관악구         0.013      0.032           0.4
#
#       아황산가스(ppm)  미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 0          0.002       31.0        20.0
# 1          0.003       19.0        14.0
# ...

# %%
#df.groupby('측정소명').mean()['오존농도(ppm)']
#df.groupby('측정소명')['오존농도(ppm)'].mean()
#df.groupby('측정소명').mean()
#df.groupby('측정소명').max() #최대값
#df.groupby('측정소명').agg('mean') #뭔가 좀더 형식을 갖춘 놈, agg를 사용하면 여러개의 함수 사용가능
df.groupby('측정소명').agg(['mean','max'])['초미세먼지(㎍/㎥)']
#df.groupby('측정소명').agg(['count','sum'])
# Out:
#            mean   max
# 측정소명
# 강남구   16.750000  40.0
# 강동구   14.029762  31.0
# 강북구   14.011905  36.0
# 강서구   18.692771  54.0
# 관악구   18.485030  42.0
# 광진구   16.759036  42.0
# 구로구   12.078788  34.0
# 금천구   19.037037  46.0
# 노원구   12.744048  33.0
# 도봉구   10.819277  25.0
# 동대문구  17.267857  42.0
# 동작구   18.975155  43.0
# 마포구   16.891566  46.0
# 서대문구  12.584337  35.0
# 서초구   13.566265  40.0
# 성동구   16.281437  44.0
# 성북구   13.578313  33.0
# 송파구   16.906780  45.0
# 양천구   18.694611  55.0
# 영등포구  18.421687  51.0
# 용산구   17.596386  44.0
# 은평구   17.608434  40.0
# 종로구   16.548193  39.0
# 중구    17.897590  54.0
# 중랑구   15.680723  35.0

# %%
df.groupby(['측정일시','측정소명']).agg('mean')['초미세먼지(㎍/㎥)']
# Out:
# 측정일시                 측정소명
# 2022-07-21 13:00:00  강남구      6.0
#                      강동구      3.0
#                      강북구      4.0
#                      강서구      9.0
#                      관악구      8.0
#                              ...
# 2022-07-28 12:00:00  용산구     26.0
#                      은평구     19.0
#                      종로구     20.0
#                      중구      22.0
#                      중랑구     21.0
# Name: 초미세먼지(㎍/㎥), Length: 4200, dtype: float64

# %%
df_pm10 = df.pivot_table(index= '측정일시',
                          columns = '측정소명',
                          values = '미세먼지(㎍/㎥)'
                         )
#df_pm10.head()
#df_pm10.to_csv('서울시 미세먼지 농도.csv', encoding = 'cp949')
df_pm10.head()
# Out:
# 측정소명                  강남구   강동구   강북구   강서구   관악구   광진구   구로구   금천구   노원구  \
# 측정일시
# 2022-07-21 13:00:00  14.0  11.0  12.0  15.0  15.0  14.0   9.0  10.0  10.0
# 2022-07-21 14:00:00  14.0  10.0  13.0  16.0  15.0   NaN  11.0   8.0  12.0
# 2022-07-21 15:00:00  15.0  12.0  12.0  15.0  15.0   NaN   7.0  14.0  11.0
# 2022-07-21 16:00:00  14.0  11.0  11.0  16.0   NaN  10.0  12.0  15.0  10.0
# 2022-07-21 17:00:00  15.0  11.0  11.0  12.0   8.0  12.0   9.0  11.0  10.0
#
# 측정소명                  도봉구  ...   성동구   성북구   송파구   양천구  영등포구   용산구   은평구  \
# 측정일시                       ...
# 2022-07-21 13:00:00   6.0  ...  14.0  13.0  28.0  13.0  15.0  14.0   9.0
# 2022-07-21 14:00:00  10.0  ...  19.0  10.0  22.0  15.0  14.0  13.0   NaN
# 2022-07-21 15:00:00   7.0  ...  15.0  13.0  29.0  12.0  15.0  15.0  18.0
# 2022-07-21 16:00:00  11.0  ...  14.0   8.0  29.0  12.0  18.0  14.0  12.0
# 2022-07-21 17:00:00  19.0  ...  18.0   8.0   NaN  15.0  16.0  15.0  12.0
#
# 측정소명                  종로구    중구   중랑구
# ...

# %%
df_pm2_5 = df.pivot_table(index= '측정일시',
                          columns = '측정소명',
                          values = '초미세먼지(㎍/㎥)'
                         )
df_pm2_5.head()
# Out:
# 측정소명                 강남구  강동구  강북구   강서구  관악구  광진구  구로구  금천구   노원구  도봉구  ...  \
# 측정일시                                                                     ...
# 2022-07-21 13:00:00  6.0  3.0  4.0   9.0  8.0  6.0  3.0  7.0   5.0  3.0  ...
# 2022-07-21 14:00:00  6.0  6.0  6.0  10.0  8.0  NaN  4.0  8.0   8.0  4.0  ...
# 2022-07-21 15:00:00  6.0  7.0  4.0   9.0  8.0  NaN  1.0  7.0   8.0  4.0  ...
# 2022-07-21 16:00:00  6.0  7.0  4.0   9.0  NaN  3.0  2.0  7.0   4.0  3.0  ...
# 2022-07-21 17:00:00  6.0  5.0  4.0   7.0  7.0  6.0  2.0  8.0  10.0  6.0  ...
#
# 측정소명                  성동구   성북구   송파구   양천구  영등포구  용산구   은평구  종로구    중구  중랑구
# 측정일시
# 2022-07-21 13:00:00   5.0   9.0  12.0  11.0   8.0  9.0  10.0  7.0   6.0  7.0
# 2022-07-21 14:00:00  12.0  10.0   5.0  10.0   8.0  6.0   9.0  5.0   7.0  6.0
# 2022-07-21 15:00:00   9.0   8.0  14.0   9.0   7.0  7.0  10.0  4.0   6.0  9.0
# 2022-07-21 16:00:00   5.0   5.0   7.0  10.0  11.0  9.0  11.0  7.0  10.0  3.0
# ...

# %%
df_pm2_5.to_csv('서울시 초미세먼지 농도.csv', encoding = 'cp949')

# %%
ls
# Out:
#  C 드라이브의 볼륨: Local Disk
#  볼륨 일련 번호: 8697-6595
#
#  C:\Users\box15\Myjupyter\광운대 파이썬 심화 디렉터리
#
# 2022-07-28  오후 01:42    <DIR>          .
# 2022-07-25  오후 01:07    <DIR>          ..
# 2022-07-28  오후 01:12    <DIR>          .ipynb_checkpoints
# 2022-07-27  오후 02:28         2,326,525 age.csv
# 2022-07-28  오후 01:12           265,649 atmospher.csv
# 2022-07-28  오후 01:06            83,778 gapminder.csv
# 2022-07-27  오후 03:03         4,275,395 gen.csv
# 2022-07-26  오후 02:42           354,728 Matplotlib.ipynb
# 2022-07-25  오후 02:54            28,870 Numpy.ipynb
# 2022-07-26  오후 01:39            97,177 Pandas.ipynb
# 2022-07-26  오후 03:41           352,692 Seaborn.ipynb
# 2022-07-26  오후 03:42         1,223,233 seoul.csv
# 2022-07-28  오후 01:06            57,732 seoul_municipalities_geo_simple.json
# 2022-07-28  오후 01:21    <DIR>          강의 자료
# 2022-07-25  오후 03:29               197 급여정보.csv
# 2022-07-26  오후 01:21             5,707 급여정보2.xlsx
# ...

# %%
import matplotlib 
from matplotlib import font_manager, rc
import platform

if platform.system() == 'Windows':
# 윈도우인 경우
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:    
# Mac 인 경우
    rc('font', family='AppleGothic')
    
matplotlib.rcParams['axes.unicode_minus'] = False   
#그래프에서 마이너스 기호가 표시되도록 하는 설정입니다.

# %%
plt.figure(figsize=(10,5))
plt.plot(df_pm10.index,
        df_pm10['강동구'],
        label = '강동구미세먼지')
plt.plot(df_pm10.index,
        df_pm10['강서구'],
        label = '강서구미세먼지')
plt.show()

# %%
df_pm2_5_mean = df.groupby('측정소명').mean()['초미세먼지(㎍/㎥)']
df_pm2_5_mean.head()
# Out:
# 측정소명
# 강남구    16.750000
# 강동구    14.029762
# 강북구    14.011905
# 강서구    18.692771
# 관악구    18.485030
# Name: 초미세먼지(㎍/㎥), dtype: float64

# %%
x=df_pm2_5_mean.index
y=df_pm2_5_mean

plt.figure(figsize=(15,5))
plt.bar(x,y)
plt.show()

# %%
import seaborn as sns

# %%
x=df_pm2_5_mean.index
y=df_pm2_5_mean

plt.figure(figsize=(15,5))

sns.barplot(x,y)

plt.show()
# Out:
# C:\Users\box15\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pd.melt(df_pm10)
# Out:
#      측정소명  value
# 0     강남구   14.0
# 1     강남구   14.0
# 2     강남구   15.0
# 3     강남구   14.0
# 4     강남구   15.0
# ...   ...    ...
# 4195  중랑구   24.0
# 4196  중랑구   27.0
# 4197  중랑구   28.0
# 4198  중랑구   30.0
# 4199  중랑구   28.0
#
# [4200 rows x 2 columns]

# %%
plt.figure(figsize = (20,5))
plt.title('서울 구별 미세먼지 분포(최근 7일)')

sns.boxplot(data=pd.melt(df_pm10),
           x = '측정소명',
           y = 'value')
plt.show()
